# %% [markdown]
# # 1. Dados das empresas

# %% [markdown]
# O objetivo desse primeiro trecho é de extrair apenas o documento descritivo das companhias de capital aberto extraído da CVM
#
# Com isso, vamos poder filtrar as empresas de acordo com a característica que queremos e pegar os códigos de empresa

# %%
# Import de pacotes
import pandas as pd
import requests
import zipfile
import io

# %%
r = requests.get('http://dados.cvm.gov.br/dados/CIA_ABERTA/CAD/DADOS/cad_cia_aberta.csv')

# %%
lines = [i.strip().split(';') for i in r.text.split('\n')]

# %%
df = pd.DataFrame(lines[1:], columns = lines[0])

# %%
df.head(2)
# Out:
#              CNPJ_CIA                 DENOM_SOCIAL  \
# 0  08.773.135/0001-00              2W ENERGIA S.A.
# 1  11.396.633/0001-87  3A COMPANHIA SECURITIZADORA
#
#                          DENOM_COMERC      DT_REG    DT_CONST   DT_CANCEL  \
# 0                       BANCO BESA SA  2020-10-29  2007-03-23
# 1  TRIPLO A  COMPANHIA SECURITIZADORA  2010-03-08  2009-11-03  2015-12-18
#
#                              MOTIVO_CANCEL        SIT  DT_INI_SIT CD_CVM  ...  \
# 0                                               ATIVO  2020-10-29  25224  ...
# 1  Cancelamento Voluntário - IN CVM 480/09  CANCELADA  2015-12-18  21954  ...
#
#   UF_RESP PAIS_RESP  CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 0      SP             4707000           11  39579400
# 1      RJ            20020000           21  22338867           21  22338867
#
#                    EMAIL_RESP        CNPJ_AUDITOR  \
# 0         ri@2wenergia.com.br  61.366.936/0001-25
# 1  juridico@triploasec.com.br  60.525.706/0001-07
#
#                                              AUDITOR
# 0    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 1  MOORE STEPHENS LIMA LUCCHESI AUDITORES INDEPEN...
#
# [2 rows x 47 columns]

# %% [markdown]
# Filtro intermediário

# %%
jhsf = '08.294.224/0001-65'

# %%
jhsf_data = df[df['CNPJ_CIA'] == jhsf]

# %%
jhsf_data
# Out:
#                 CNPJ_CIA           DENOM_SOCIAL DENOM_COMERC      DT_REG  \
# 1473  08.294.224/0001-65  JHSF PARTICIPAÇÕES SA         JHSF  2007-04-04
#
#         DT_CONST DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT CD_CVM  ...  \
# 1473  2006-06-29                          ATIVO  2007-04-04  20605  ...
#
#      UF_RESP PAIS_RESP CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 1473      SP            5502001           11  37025473           11  37022370
#
#           EMAIL_RESP        CNPJ_AUDITOR  \
# 1473  ri@jhsf.com.br  61.366.936/0001-25
#
#                                               AUDITOR
# 1473  ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
#
# [1 rows x 47 columns]

# %%
lista_cnpjs = ['05.878.397/0001-32', '07.816.890/0001-53', '51.218.147/0001-93', '06.977.751/0001-49','06.977.745/0001-91']

# %%
type(lista_cnpjs)
# Out:
# list

# %%
filtrados = df[df['CNPJ_CIA'].isin(lista_cnpjs)]

# %%
filtrados.shape
# Out:
# (8, 47)

# %%
filtrados
# Out:
#                 CNPJ_CIA                              DENOM_SOCIAL  \
# 71    05.878.397/0001-32      ALIANSCE SONAE SHOPPING CENTERS S.A.
# 72    05.878.397/0001-32      ALIANSCE SONAE SHOPPING CENTERS S.A.
# 379   06.977.745/0001-91               BR MALLS PARTICIPAÇOES S.A.
# 380   06.977.751/0001-49                        BR PROPERTIES S.A.
# 381   06.977.751/0001-49                        BR PROPERTIES S.A.
# 1334  51.218.147/0001-93  IGUATEMI EMPRESA DE SHOPPING CENTERS S/A
# 1741  07.816.890/0001-53           MULTIPLAN EMP. IMOBILIARIOS S/A
# 1742  07.816.890/0001-53           MULTIPLAN EMP. IMOBILIARIOS S/A
#
#                                   DENOM_COMERC      DT_REG    DT_CONST  \
# 71        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 72        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 379                BR MALLS PARTICIPAÇOES S.A.  2006-01-04  2004-05-26
# 380                         BR PROPERTIES S.A.  2006-01-04  2004-05-26
# 381                         BR PROPERTIES S.A.  2006-01-04  2004-05-26
# 1334  IGUATEMI EMPRESA DE SHOPPING CENTERS S/A  2007-02-02  1979-05-23
# 1741                                 MULTIPLAN  2007-07-25  2005-12-30
# 1742                                 MULTIPLAN  2007-07-25  2005-12-30
#
#      DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT CD_CVM  ... UF_RESP PAIS_RESP  \
# 71                            ATIVO  2011-02-01  22357  ...      RJ
# 72                            ATIVO  2011-02-01  22357  ...      RJ
# 379                           ATIVO  2006-01-04  19909  ...      RJ
# 380                           ATIVO  2006-01-04  19925  ...      SP
# 381                           ATIVO  2006-01-04  19925  ...      SP
# 1334                          ATIVO  2007-02-02  20494  ...      RJ
# 1741                          ATIVO  2007-07-25  20982  ...      RJ
# 1742                          ATIVO  2007-07-25  20982  ...      RJ
#
#       CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 71    22431050           21  21767272           21  21767229
# 72    22431050           21  21767272           21  21767229
# 379   22430041           21  31389900           21  31389901
# 380    4578000           11  32011000           11  32011001
# 381    4578000           11  32011000           11  32011001
# 1334   1455070           11  30377037            0         0
# 1741  22640102           21  30315224           21  30315322
# 1742  22640102           21  30315224           21  30315322
#
#                    EMAIL_RESP        CNPJ_AUDITOR  \
# 71    ri@alianscesonae.com.br  61.366.936/0001-25
# 72    ri@alianscesonae.com.br  61.366.936/0001-25
# 379      gd-ri@brmalls.com.br  61.366.936/0001-25
# 380            ri@brpr.com.br  57.755.217/0001-29
# 381            ri@brpr.com.br  57.755.217/0001-29
# 1334       ri@iguatemi.com.br  49.928.567/0001-11
# 1741      ri@multiplan.com.br  57.755.217/0001-29
# 1742      ri@multiplan.com.br  57.755.217/0001-29
#
#                                                 AUDITOR
# 71      ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 72      ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 379     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 380                  KPMG AUDITORES INDEPENDENTES LTDA.
# 381                  KPMG AUDITORES INDEPENDENTES LTDA.
# 1334  DELOITTE TOUCHE TOHMATSU AUDITORES INDEPENDENT...
# 1741                 KPMG AUDITORES INDEPENDENTES LTDA.
# 1742                 KPMG AUDITORES INDEPENDENTES LTDA.
#
# [8 rows x 47 columns]

# %% [markdown]
# Procurando por empresas específicas, que tenham uma característica em comum na sua denominação comercial

# %%
searchfor = ['MULTIPLAN', 'MALL', 'IGUATEMI', 'SHOPP']
shoppings = df[df.DENOM_SOCIAL.str.contains('|'.join(searchfor), na=False)]

# %%
shoppings.head()
# Out:
#                CNPJ_CIA                          DENOM_SOCIAL  \
# 70   06.082.980/0001-03         ALIANSCE SHOPPING CENTERS S/A
# 71   05.878.397/0001-32  ALIANSCE SONAE SHOPPING CENTERS S.A.
# 72   05.878.397/0001-32  ALIANSCE SONAE SHOPPING CENTERS S.A.
# 82   82.120.676/0001-83  ALMEIDA JUNIOR SHOPPING CENTERS S.A.
# 119  00.979.769/0001-01                     ANCAR SHOPPING SA
#
#                              DENOM_COMERC      DT_REG    DT_CONST   DT_CANCEL  \
# 70                               ALIANSCE  2008-01-18  2004-01-01  2019-08-05
# 71   ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 72   ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 82   ALMEIDA JUNIOR SHOPPING CENTERS S.A.  2021-11-22  1990-08-01
# 119                                 ANCAR  1996-01-11  1995-12-01  2001-11-30
#
#                MOTIVO_CANCEL        SIT  DT_INI_SIT CD_CVM  ... UF_RESP  \
# 70   ELISÃO POR INCORPORAÇÃO  CANCELADA  2019-08-05  21300  ...      RJ
# 71                                ATIVO  2011-02-01  22357  ...      RJ
# 72                                ATIVO  2011-02-01  22357  ...      RJ
# 82                                ATIVO  2021-11-22  26395  ...      SP
# 119  ELISÃO POR INCORPORAÇÃO  CANCELADA  2001-11-30  15326  ...      RJ
#
#     PAIS_RESP  CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 70             22431050           21  21767272           21  21767229
# 71             22431050           21  21767272           21  21767229
# 72             22431050           21  21767272           21  21767229
# 82              1452000           11  37073333            0         0
# 119            20011020           21  38062700           21  38062749
#
#                   EMAIL_RESP        CNPJ_AUDITOR  \
# 70        ri@aliansce.com.br  61.562.112/0001-20
# 71   ri@alianscesonae.com.br  61.366.936/0001-25
# 72   ri@alianscesonae.com.br  61.366.936/0001-25
# 82   ri@almeidajunior.com.br  61.366.936/0001-25
# 119       ancar@ancar.com.br  33.017.310/0001-78
#
#                                                AUDITOR
# 70   PRICEWATERHOUSECOOPERS AUDITORES INDEPENDENTES...
# 71     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 72     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 82     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 119                                         RUHTRA S/C
#
# [5 rows x 47 columns]

# %%
shoppings_ativos = shoppings[shoppings['SIT'] == 'ATIVO']

# %%
shoppings_ativos.shape
# Out:
# (11, 47)

# %%
shoppings_ativos
# Out:
#                 CNPJ_CIA                               DENOM_SOCIAL  \
# 71    05.878.397/0001-32       ALIANSCE SONAE SHOPPING CENTERS S.A.
# 72    05.878.397/0001-32       ALIANSCE SONAE SHOPPING CENTERS S.A.
# 82    82.120.676/0001-83       ALMEIDA JUNIOR SHOPPING CENTERS S.A.
# 379   06.977.745/0001-91                BR MALLS PARTICIPAÇOES S.A.
# 1236  08.764.621/0001-53  GENERAL SHOPPING E OUTLETS DO BRASIL S.A.
# 1237  08.764.621/0001-53  GENERAL SHOPPING E OUTLETS DO BRASIL S.A.
# 1334  51.218.147/0001-93   IGUATEMI EMPRESA DE SHOPPING CENTERS S/A
# 1335  60.543.816/0001-93                              IGUATEMI S.A.
# 1472  07.859.510/0001-68                            JHSF MALLS S.A.
# 1741  07.816.890/0001-53            MULTIPLAN EMP. IMOBILIARIOS S/A
# 1742  07.816.890/0001-53            MULTIPLAN EMP. IMOBILIARIOS S/A
#
#                                   DENOM_COMERC      DT_REG    DT_CONST  \
# 71        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 72        ALIANSCE SONAE SHOPPING CENTERS S.A.  2011-02-01  2003-07-17
# 82        ALMEIDA JUNIOR SHOPPING CENTERS S.A.  2021-11-22  1990-08-01
# 379                BR MALLS PARTICIPAÇOES S.A.  2006-01-04  2004-05-26
# 1236                GENERAL SHOPPING BRASIL SA  2007-07-26  2006-03-06
# 1237                GENERAL SHOPPING BRASIL SA  2007-07-26  2006-03-06
# 1334  IGUATEMI EMPRESA DE SHOPPING CENTERS S/A  2007-02-02  1979-05-23
# 1335                             IGUATEMI S.A.  1946-03-12  1946-01-24
# 1472                           JHSF MALLS S.A.  2018-06-25  2005-12-08
# 1741                                 MULTIPLAN  2007-07-25  2005-12-30
# 1742                                 MULTIPLAN  2007-07-25  2005-12-30
#
#      DT_CANCEL MOTIVO_CANCEL    SIT  DT_INI_SIT CD_CVM  ... UF_RESP PAIS_RESP  \
# 71                            ATIVO  2011-02-01  22357  ...      RJ
# 72                            ATIVO  2011-02-01  22357  ...      RJ
# 82                            ATIVO  2021-11-22  26395  ...      SP
# 379                           ATIVO  2006-01-04  19909  ...      RJ
# 1236                          ATIVO  2007-07-26  21008  ...      SP
# 1237                          ATIVO  2007-07-26  21008  ...      SP
# 1334                          ATIVO  2007-02-02  20494  ...      RJ
# 1335                          ATIVO  1946-03-12   8672  ...      SP
# 1472                          ATIVO  2018-06-25  24473  ...      SP
# 1741                          ATIVO  2007-07-25  20982  ...      RJ
# 1742                          ATIVO  2007-07-25  20982  ...      RJ
#
#       CEP_RESP DDD_TEL_RESP  TEL_RESP DDD_FAX_RESP  FAX_RESP  \
# 71    22431050           21  21767272           21  21767229
# 72    22431050           21  21767272           21  21767229
# 82     1452000           11  37073333            0         0
# 379   22430041           21  31389900           21  31389901
# 1236   1228200          011  31595100          011  31590122
# 1237   1228200          011  31595100          011  31590122
# 1334   1455070           11  30377037            0         0
# 1335   1455070            0         0            0         0
# 1472   5502001           11  37021900           11  37022370
# 1741  22640102           21  30315224           21  30315322
# 1742  22640102           21  30315224           21  30315322
#
#                       EMAIL_RESP        CNPJ_AUDITOR  \
# 71       ri@alianscesonae.com.br  61.366.936/0001-25
# 72       ri@alianscesonae.com.br  61.366.936/0001-25
# 82       ri@almeidajunior.com.br  61.366.936/0001-25
# 379         gd-ri@brmalls.com.br  61.366.936/0001-25
# 1236  dri@generalshopping.com.br  51.703.924/0001-95
# 1237  dri@generalshopping.com.br  51.703.924/0001-95
# 1334          ri@iguatemi.com.br  49.928.567/0001-11
# 1335          ri@iguatemi.com.br  49.928.567/0001-11
# 1472         ri@jhsfmalls.com.br  61.366.936/0001-25
# 1741         ri@multiplan.com.br  57.755.217/0001-29
# 1742         ri@multiplan.com.br  57.755.217/0001-29
#
#                                                 AUDITOR
# 71      ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 72      ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 82      ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 379     ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 1236  COTRIM & ASSOCIADOS AUDITORES INDEPENDENTES - ...
# 1237  COTRIM & ASSOCIADOS AUDITORES INDEPENDENTES - ...
# 1334  DELOITTE TOUCHE TOHMATSU AUDITORES INDEPENDENT...
# 1335  DELOITTE TOUCHE TOHMATSU AUDITORES INDEPENDENT...
# 1472    ERNST & YOUNG AUDITORES INDEPENDENTES S/S LTDA.
# 1741                 KPMG AUDITORES INDEPENDENTES LTDA.
# 1742                 KPMG AUDITORES INDEPENDENTES LTDA.
#
# [11 rows x 47 columns]

# %%
CNPJ = '08.294.224/0001-65'

# %%
empresas = list(filtrados['CD_CVM'])

# %%
empresas
# Out:
# ['22357', '22357', '19909', '19925', '19925', '20494', '20982', '20982']

# %% [markdown]
# # 2. Extraindo as demonstrações financeiras

# %% [markdown]
# Precisamos obter os códigos CVM das empresas que queremos obter

# %% [markdown]
# Uma vez que sabemos os códigos a partir da tabela anterior, vamos transformar essa coluna em uma lista

# %%
#empresas = list(shoppings_ativos['CD_CVM'])

# %%
empresas
# Out:
# ['22357', '22357', '19909', '19925', '19925', '20494', '20982', '20982']

# %% [markdown]
# Quais as demonstrações que você precisa?
#
# Em 'arquivo', determine o tipo do demonstrativo e o ano
#
# O 'arquivo' precisa estar contido na pasta zipada da CVM

# %%
arquivo = 'itr_cia_aberta_DRE_con_2021.csv'
link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip'

# %%
r = requests.get(link)

# %%
zf = zipfile.ZipFile(io.BytesIO(r.content))

# %%
zf
# Out:
# <zipfile.ZipFile file=<_io.BytesIO object at 0x7f67c5791810> mode='r'>

# %% [markdown]
# Qual dos arquivos você quer abrir

# %%
zf = zf.open(arquivo)

# %%
lines = zf.readlines()

# %%
lines = [i.strip().decode('ISO-8859-1') for i in lines]

# %%
lines = [i.split(';') for i in lines]

# %%
df = pd.DataFrame(lines[1:], columns = lines[0])

# %%
df.head()
# Out:
#              CNPJ_CIA    DT_REFER VERSAO        DENOM_CIA  CD_CVM  \
# 0  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 1  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 2  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 3  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 4  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 4  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                              DS_CONTA  \
# 0   2021-01-01   2021-03-31     3.01  Receitas de Intermediação Financeira
# 1   2022-01-01   2022-03-31     3.01  Receitas de Intermediação Financeira
# 2   2021-01-01   2021-03-31  3.01.01                      Receita de Juros
# 3   2022-01-01   2022-03-31  3.01.01                      Receita de Juros
# 4   2021-01-01   2021-03-31     3.02  Despesas de Intermediação Financeira
#
#               VL_CONTA ST_CONTA_FIXA
# 0  23354279.0000000000             S
# 1  48490439.0000000000             S
# 2  23354279.0000000000             N
# 3  48490439.0000000000             N
# 4  -9590313.0000000000             S

# %%
df.shape
# Out:
# (156822, 15)

# %%
#df.CD_CVM.unique()

# %%
df.dtypes
# Out:
# CNPJ_CIA         object
# DT_REFER         object
# VERSAO           object
# DENOM_CIA        object
# CD_CVM           object
# GRUPO_DFP        object
# MOEDA            object
# ESCALA_MOEDA     object
# ORDEM_EXERC      object
# DT_INI_EXERC     object
# DT_FIM_EXERC     object
# CD_CONTA         object
# DS_CONTA         object
# VL_CONTA         object
# ST_CONTA_FIXA    object
# dtype: object

# %%
type(empresas[0])
# Out:
# str

# %%
df.head()
# Out:
#              CNPJ_CIA    DT_REFER VERSAO        DENOM_CIA  CD_CVM  \
# 0  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 1  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 2  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 3  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
# 4  00.000.000/0001-91  2022-03-31      1  BCO BRASIL S.A.  001023
#
#                                     GRUPO_DFP MOEDA ESCALA_MOEDA ORDEM_EXERC  \
# 0  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 1  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 2  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
# 3  DF Consolidado - Demonstração do Resultado  REAL          MIL      ÚLTIMO
# 4  DF Consolidado - Demonstração do Resultado  REAL          MIL   PENÚLTIMO
#
#   DT_INI_EXERC DT_FIM_EXERC CD_CONTA                              DS_CONTA  \
# 0   2021-01-01   2021-03-31     3.01  Receitas de Intermediação Financeira
# 1   2022-01-01   2022-03-31     3.01  Receitas de Intermediação Financeira
# 2   2021-01-01   2021-03-31  3.01.01                      Receita de Juros
# 3   2022-01-01   2022-03-31  3.01.01                      Receita de Juros
# 4   2021-01-01   2021-03-31     3.02  Despesas de Intermediação Financeira
#
#               VL_CONTA ST_CONTA_FIXA
# 0  23354279.0000000000             S
# 1  48490439.0000000000             S
# 2  23354279.0000000000             N
# 3  48490439.0000000000             N
# 4  -9590313.0000000000             S

# %%
#df.DENOM_CIA.unique()

# %% [markdown]
# Quais são as datas dos demonstrativos?

# %%
df.DT_FIM_EXERC.unique()
# Out:
# array(['2021-03-31', '2022-03-31', '2021-06-30', '2022-06-30',
#        '2021-09-30', '2022-09-30', '2021-05-31', '2022-05-31',
#        '2021-08-31', '2022-08-31', '2021-11-30', '2022-11-30'],
#       dtype=object)

# %%
df.DT_REFER.unique()
# Out:
# array(['2022-03-31', '2022-06-30', '2022-09-30', '2022-05-31',
#        '2022-08-31', '2022-11-30'], dtype=object)

# %% [markdown]
# Vamos testar um filtro para uma empresa específica

# %%
filtro = df[df['CD_CVM']=='022357']

# %%
filtro.shape
# Out:
# (300, 15)

# %%
filtro.DT_REFER.unique()
# Out:
# array(['2022-03-31', '2022-06-30', '2022-09-30'], dtype=object)

# %%
filtro.DT_FIM_EXERC.unique()
# Out:
# array(['2021-03-31', '2022-03-31', '2021-06-30', '2022-06-30',
#        '2021-09-30', '2022-09-30'], dtype=object)

# %%
filtro.head()
# Out:
#                  CNPJ_CIA    DT_REFER VERSAO  \
# 28682  05.878.397/0001-32  2022-03-31      1
# 28683  05.878.397/0001-32  2022-03-31      1
# 28684  05.878.397/0001-32  2022-03-31      1
# 28685  05.878.397/0001-32  2022-03-31      1
# 28686  05.878.397/0001-32  2022-03-31      1
#
#                                   DENOM_CIA  CD_CVM  \
# 28682  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28683  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28684  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28685  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28686  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
#
#                                         GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 28682  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28683  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28684  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28685  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28686  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#       ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC CD_CONTA  \
# 28682   PENÚLTIMO   2021-01-01   2021-03-31     3.01
# 28683      ÚLTIMO   2022-01-01   2022-03-31     3.01
# 28684   PENÚLTIMO   2021-01-01   2021-03-31     3.02
# 28685      ÚLTIMO   2022-01-01   2022-03-31     3.02
# 28686   PENÚLTIMO   2021-01-01   2021-03-31     3.03
#
#                                      DS_CONTA           VL_CONTA ST_CONTA_FIXA
# 28682  Receita de Venda de Bens e/ou Serviços  196995.0000000000             S
# 28683  Receita de Venda de Bens e/ou Serviços  267363.0000000000             S
# 28684   Custo dos Bens e/ou Serviços Vendidos  -71589.0000000000             S
# 28685   Custo dos Bens e/ou Serviços Vendidos  -79203.0000000000             S
# 28686                         Resultado Bruto  125406.0000000000             S

# %%
filtro['VL_AJUSTADO'] = pd.to_numeric(filtro['VL_CONTA'])
# Out:
# <ipython-input-47-d42ea9e6698f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro['VL_AJUSTADO'] = pd.to_numeric(filtro['VL_CONTA'])

# %%
filtro.head()
# Out:
#                  CNPJ_CIA    DT_REFER VERSAO  \
# 28682  05.878.397/0001-32  2022-03-31      1
# 28683  05.878.397/0001-32  2022-03-31      1
# 28684  05.878.397/0001-32  2022-03-31      1
# 28685  05.878.397/0001-32  2022-03-31      1
# 28686  05.878.397/0001-32  2022-03-31      1
#
#                                   DENOM_CIA  CD_CVM  \
# 28682  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28683  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28684  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28685  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
# 28686  ALIANSCE SONAE SHOPPING CENTERS S.A.  022357
#
#                                         GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 28682  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28683  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28684  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28685  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 28686  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#       ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC CD_CONTA  \
# 28682   PENÚLTIMO   2021-01-01   2021-03-31     3.01
# 28683      ÚLTIMO   2022-01-01   2022-03-31     3.01
# 28684   PENÚLTIMO   2021-01-01   2021-03-31     3.02
# 28685      ÚLTIMO   2022-01-01   2022-03-31     3.02
# 28686   PENÚLTIMO   2021-01-01   2021-03-31     3.03
#
#                                      DS_CONTA           VL_CONTA  \
# 28682  Receita de Venda de Bens e/ou Serviços  196995.0000000000
# 28683  Receita de Venda de Bens e/ou Serviços  267363.0000000000
# 28684   Custo dos Bens e/ou Serviços Vendidos  -71589.0000000000
# 28685   Custo dos Bens e/ou Serviços Vendidos  -79203.0000000000
# 28686                         Resultado Bruto  125406.0000000000
#
#       ST_CONTA_FIXA  VL_AJUSTADO
# 28682             S     196995.0
# 28683             S     267363.0
# 28684             S     -71589.0
# 28685             S     -79203.0
# 28686             S     125406.0

# %% [markdown]
# Teste de exportação - Como sai o demonstrativo num csv?
#
# Vamos ver para qual diretório o arquivo é exportado

# %%
filtro.to_csv('Balanço_JHDF_tri_02.csv', sep = ';' ,encoding= 'ISO-8859-1')

# %% [markdown]
# # 3. Automatização da exportação

# %% [markdown]
# Uma vez que a exportação funcionou, vamos criar um loop que vai fazer a captura de vários demonstrativos diferentes de uma vez, e depois filtrar empresas específicas.
#
# Quando isso for concluído, ele vai gerar um excel por empresa, e cada aba será um demonstrativo diferente
#
# Crie uma lista com os códigos das empresas que deseja (ou essa lista pode ser a mesma criada no item 1 desse código)

# %%
# !pip install xlsxwriter
import xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.7-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 KB 5.8 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.7

# %% [markdown]
# ## Executável

# %%
demonstrativos = ['DFC_MD', 'DFC_MI','BPA', 'DRE', 'BPP']

# %%
#empresas = list(shoppings_ativos['CD_CVM'])

# %%
import time
start_time = time.time()

import zipfile
import io
import xlsxwriter

lista_listas = []

a = 0

for j in empresas:

  c = 0

  lista_df = []

  for k in demonstrativos:

    link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2021.zip'

    r = requests.get(link)

    zf = zipfile.ZipFile(io.BytesIO(r.content))

    arquivo = 'itr_cia_aberta_' + str(k) + '_con_2021.csv'

    zf = zf.open(arquivo)

    lines = zf.readlines()

    lines = [i.strip().decode('ISO-8859-1') for i in lines]

    lines = [i.split(';') for i in lines]

    c += 1 

    df = pd.DataFrame(lines[1:], columns = lines[0])

    df['VL_AJUSTADO'] = pd.to_numeric(df['VL_CONTA'])

    filtro = df[df['CD_CVM']== '0' + str(j)]

    lista_df.append(filtro)

    print(f'Trabalhando com a empresa {j} e sua demonstração {k}. As dimensões são {filtro.shape} ')

  lista_listas.append(lista_df)

  # Create a Pandas Excel writer using XlsxWriter as the engine.
  writer = pd.ExcelWriter(f'Demonstrativos Empresa {str(j)}.xlsx', engine='xlsxwriter')

  # Write each dataframe to a different worksheet.
  lista_listas[a][0].to_excel(writer, sheet_name='DFC_MD',encoding= 'ISO-8859-1')
  lista_listas[a][1].to_excel(writer, sheet_name='DFC_MI',encoding= 'ISO-8859-1')
  lista_listas[a][2].to_excel(writer, sheet_name='BPA',encoding= 'ISO-8859-1')
  lista_listas[a][3].to_excel(writer, sheet_name='DRE',encoding= 'ISO-8859-1')
  lista_listas[a][4].to_excel(writer, sheet_name='BPP',encoding= 'ISO-8859-1')

  a += 1

  print(f'Arquivo excel com os demonstrativos da empresa {j} já exportado. \n')

  # Close the Pandas Excel writer and output the Excel file.
  writer.save()


print("O tempo de execução desse programa foi de %s segundos ---" % (time.time() - start_time))
# Out:
# Trabalhando com a empresa 22357 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e sua demonstração DFC_MI. As dimensões são (430, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPA. As dimensões são (420, 15)
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (300, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPP. As dimensões são (692, 15)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 22357 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e sua demonstração DFC_MI. As dimensões são (430, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPA. As dimensões são (420, 15)
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (300, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPP. As dimensões são (692, 15)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 19909 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19909 e sua demonstração DFC_MI. As dimensões são (434, 16)
# Trabalhando com a empresa 19909 e sua demonstração BPA. As dimensões são (390, 15)
# Trabalhando com a empresa 19909 e sua demonstração DRE. As dimensões são (340, 16)
# Trabalhando com a empresa 19909 e sua demonstração BPP. As dimensões são (702, 15)
# Arquivo excel com os demonstrativos da empresa 19909 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19925 e sua demonstração DFC_MI. As dimensões são (392, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPA. As dimensões são (394, 15)
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPP. As dimensões são (694, 15)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19925 e sua demonstração DFC_MI. As dimensões são (392, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPA. As dimensões são (394, 15)
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPP. As dimensões são (694, 15)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 20494 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20494 e sua demonstração DFC_MI. As dimensões são (308, 16)
# Trabalhando com a empresa 20494 e sua demonstração BPA. As dimensões são (408, 15)
# Trabalhando com a empresa 20494 e sua demonstração DRE. As dimensões são (332, 16)
# Trabalhando com a empresa 20494 e sua demonstração BPP. As dimensões são (666, 15)
# Arquivo excel com os demonstrativos da empresa 20494 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e sua demonstração DFC_MI. As dimensões são (364, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPA. As dimensões são (390, 15)
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (374, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPP. As dimensões são (734, 15)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e sua demonstração DFC_MI. As dimensões são (364, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPA. As dimensões são (390, 15)
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (374, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPP. As dimensões são (734, 15)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# O tempo de execução desse programa foi de 168.50314378738403 segundos ---

# %% [markdown]
# #4. Transformando os dados

# %% [markdown]
# ##4.1. Instalando e importando bibliotecas

# %%
#Precisamos instalar duas bibliotecas

#Plotly para visualização de dados
# !pip install Plotly

#Investpy para capturar dados de preços das ações

# !pip install investpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Plotly in /usr/local/lib/python3.8/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from Plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from Plotly) (8.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting investpy
#   Downloading investpy-1.0.8.tar.gz (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 82.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Unidecode>=1.1.1
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.2.0 in /usr/local/lib/python3.8/dist-packages (from investpy) (57.4.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from investpy) (1.21.6)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.8/dist-packages (from investpy) (1.3.5)
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.8/dist-packages (from investpy) (4.9.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.8/dist-packages (from investpy) (2.25.1)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.8/dist-packages (from investpy) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.1->investpy) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->investpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->investpy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->investpy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->investpy) (4.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->investpy) (1.15.0)
# Building wheels for collected packages: investpy
#   Building wheel for investpy (setup.py) ... done
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481592 sha256=b2205ff74c1cc3d3ef7a3ae46e1d5f656ef8244a68865c70cbb7023bf75084e2
#   Stored in directory: /root/.cache/pip/wheels/9a/6f/8e/21466569113166e5859029b97fcae2b81af57063ed9faf698e
# Successfully built investpy
# Installing collected packages: Unidecode, investpy
# Successfully installed Unidecode-1.3.6 investpy-1.0.8

# %%
#Importar todas as bibliotecas

import plotly
import investpy
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ##4.2. Tabela DRE

# %%
#Capturar os arquivos que estão no diretório criado na etapa do webscrapping

caminho = os.getcwd()
arquivos = os.listdir(caminho)
arquivos
# Out:
# ['.config',
#  'Demonstrativos Empresa 20494.xlsx',
#  'Balanço_JHDF_tri_02.csv',
#  'Demonstrativos Empresa 19909.xlsx',
#  'Demonstrativos Empresa 22357.xlsx',
#  'Demonstrativos Empresa 19925.xlsx',
#  'Demonstrativos Empresa 20982.xlsx',
#  'sample_data']

# %%
#Juntamos todos esses xslxs em uma lista

arquivos_xls = [f for f in arquivos if f[-1] == 'x']
arquivos_xls
# Out:
# ['Demonstrativos Empresa 20494.xlsx',
#  'Demonstrativos Empresa 19909.xlsx',
#  'Demonstrativos Empresa 22357.xlsx',
#  'Demonstrativos Empresa 19925.xlsx',
#  'Demonstrativos Empresa 20982.xlsx']

# %%
#Criar o dataframe DRE

dre = pd.DataFrame()

# %%
#Vamos juntar todos os arquivos xlsx em uma grande tabela DRE

for f in arquivos_xls:
  drexls = pd.read_excel(f, sheet_name='DRE')
  dre = dre.append(drexls)

# %%
dre
# Out:
#      Unnamed: 0            CNPJ_CIA    DT_REFER  VERSAO  \
# 0        116008  51.218.147/0001-93  2022-03-31       1
# 1        116009  51.218.147/0001-93  2022-03-31       1
# 2        116010  51.218.147/0001-93  2022-03-31       1
# 3        116011  51.218.147/0001-93  2022-03-31       1
# 4        116012  51.218.147/0001-93  2022-03-31       1
# ..          ...                 ...         ...     ...
# 369       36541  07.816.890/0001-53  2022-09-30       1
# 370       36542  07.816.890/0001-53  2022-09-30       1
# 371       36543  07.816.890/0001-53  2022-09-30       1
# 372       36544  07.816.890/0001-53  2022-09-30       1
# 373       36545  07.816.890/0001-53  2022-09-30       1
#
#                                     DENOM_CIA  CD_CVM  \
# 0    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A   20494
# 1    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A   20494
# 2    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A   20494
# 3    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A   20494
# 4    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A   20494
# ..                                        ...     ...
# 369    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.   20982
# 370    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.   20982
# 371    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.   20982
# 372    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.   20982
# 373    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.   20982
#
#                                       GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0    DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1    DF Consolidado - Demonstração do Resultado  REAL          MIL
# 2    DF Consolidado - Demonstração do Resultado  REAL          MIL
# 3    DF Consolidado - Demonstração do Resultado  REAL          MIL
# 4    DF Consolidado - Demonstração do Resultado  REAL          MIL
# ..                                          ...   ...          ...
# 369  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 370  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 371  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 372  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 373  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#     ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0     PENÚLTIMO   2021-01-01   2021-03-31        3.01
# 1        ÚLTIMO   2022-01-01   2022-03-31        3.01
# 2     PENÚLTIMO   2021-01-01   2021-03-31        3.02
# 3        ÚLTIMO   2022-01-01   2022-03-31        3.02
# 4     PENÚLTIMO   2021-01-01   2021-03-31        3.03
# ..          ...          ...          ...         ...
# 369      ÚLTIMO   2022-07-01   2022-09-30     3.99.02
# 370   PENÚLTIMO   2021-01-01   2021-09-30  3.99.02.01
# 371   PENÚLTIMO   2021-07-01   2021-09-30  3.99.02.01
# 372      ÚLTIMO   2022-01-01   2022-09-30  3.99.02.01
# 373      ÚLTIMO   2022-07-01   2022-09-30  3.99.02.01
#
#                                    DS_CONTA     VL_CONTA ST_CONTA_FIXA  \
# 0    Receita de Venda de Bens e/ou Serviços  166639.0000             S
# 1    Receita de Venda de Bens e/ou Serviços  225737.0000             S
# 2     Custo dos Bens e/ou Serviços Vendidos  -77636.0000             S
# 3     Custo dos Bens e/ou Serviços Vendidos  -95719.0000             S
# 4                           Resultado Bruto   89003.0000             S
# ..                                      ...          ...           ...
# 369                  Lucro Diluído por Ação       0.0000             N
# 370                                      ON       0.4007             N
# 371                                      ON       0.0000             N
# 372                                      ON       0.8938             N
# 373                                      ON       0.0000             N
#
#      VL_AJUSTADO
# 0    166639.0000
# 1    225737.0000
# 2    -77636.0000
# 3    -95719.0000
# 4     89003.0000
# ..           ...
# 369       0.0000
# 370       0.4007
# 371       0.0000
# 372       0.8938
# 373       0.0000
#
# [1732 rows x 17 columns]

# %%
dre.iloc[-122,:]
# Out:
# Unnamed: 0                                            36424
# CNPJ_CIA                                 07.816.890/0001-53
# DT_REFER                                         2022-09-30
# VERSAO                                                    1
# DENOM_CIA            MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# CD_CVM                                                20982
# GRUPO_DFP        DF Consolidado - Demonstração do Resultado
# MOEDA                                                  REAL
# ESCALA_MOEDA                                            MIL
# ORDEM_EXERC                                          ÚLTIMO
# DT_INI_EXERC                                     2022-01-01
# DT_FIM_EXERC                                     2022-09-30
# CD_CONTA                                         3.04.02.01
# DS_CONTA                    Despesas administrativas - Sede
# VL_CONTA                                          -126371.0
# ST_CONTA_FIXA                                             N
# VL_AJUSTADO                                       -126371.0
# Name: 252, dtype: object

# %%
#Puxar uma lista com os nomes das empresas

lista_de_empresas = dre['DENOM_CIA'].unique()
lista_de_empresas = lista_de_empresas.transpose()

# %%
lista_de_empresas = lista_de_empresas.tolist()

# %%
lista_de_empresas
# Out:
# ['IGUATEMI EMPRESA DE SHOPPING CENTERS S.A',
#  'BR MALLS PARTICIPACOES S.A.',
#  'ALIANSCE SONAE SHOPPING CENTERS S.A.',
#  'BR PROPERTIES S.A.',
#  'MULTIPLAN - EMPREEND IMOBILIARIOS S.A.']

# %%
tickers = ['BRML3','ALSO3','BRPR3','IGTA3','MULT3']

# %%
n_empresas = len(lista_de_empresas)
n_empresas
# Out:
# 5

# %%
lista_de_contas = dre['DS_CONTA'].unique()
lista_de_contas = lista_de_contas.tolist()
lista_de_contas
# Out:
# ['Receita de Venda de Bens e/ou Serviços',
#  'Custo dos Bens e/ou Serviços Vendidos',
#  'Resultado Bruto',
#  'Despesas/Receitas Operacionais',
#  'Despesas com Vendas',
#  'Despesas Gerais e Administrativas',
#  'Perdas pela Não Recuperabilidade de Ativos',
#  'Outras Receitas Operacionais',
#  'Outras Despesas Operacionais',
#  'Resultado de Equivalência Patrimonial',
#  'Resultado Antes do Resultado Financeiro e dos Tributos',
#  'Resultado Financeiro',
#  'Receitas Financeiras',
#  'Despesas Financeiras',
#  'Resultado Antes dos Tributos sobre o Lucro',
#  'Imposto de Renda e Contribuição Social sobre o Lucro',
#  'Corrente',
#  'Diferido',
#  'Resultado Líquido das Operações Continuadas',
#  'Resultado Líquido de Operações Descontinuadas',
#  'Lucro/Prejuízo Líquido das Operações Descontinuadas',
#  'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas',
#  'Lucro/Prejuízo Consolidado do Período',
#  'Atribuído a Sócios da Empresa Controladora',
#  'Atribuído a Sócios Não Controladores',
#  'Lucro por Ação - (Reais / Ação)',
#  'Lucro Básico por Ação',
#  'ON',
#  'Lucro Diluído por Ação',
#  'Valor Justo de Instrumento de Capital',
#  'Ganho com valor justo de propriedade para investimento',
#  'Perda com valor justo de propriedade para investimento',
#  'Ganho/Perda com valor justo de propriedade para investimento',
#  'Variação do valor justo de propriedades para investimento',
#  'Outras receitas / (despesas) operacionais',
#  'Ganho com valor justo de propriedades para investimento',
#  'Outras receitas operacionais',
#  'Perda com valor justo de propriedades para investimento',
#  'Outras despesas operacionais',
#  'Receita Líquida da Venda de Bens e/ou Serviços',
#  'Honorários da Administração',
#  'Plano de Opção de Compra de Ações',
#  'Ganho (perda) na Alienação de Propriedades Para Investimentos',
#  'Ganho (perda) com Valor Justo das Propriedades Para Investimentos',
#  'Ganho (perda) na Alienação de Propriedades Para investimento',
#  'Ganho com Valor Justo das Propriedades Para Investimentos',
#  'Perda com Valor Justo das Propriedades Para Investimentos',
#  'Receita líquida da venda de bens e/ou serviços',
#  'Despesas gerais e adminstrativas',
#  'Honorários da administração',
#  'Plano de opção de compra de ações',
#  'Ganho com valor justo das propriedades para investimentos',
#  'Perda com valor justo das propriedades para investimentos',
#  'Despesas administrativas - Sede',
#  'Despesas Administrativas - Shopping',
#  'Despesas com projetos para locação',
#  'Despesas com projetos para venda',
#  'Despesas de remuneração baseada em opção de ações',
#  'Depreciações e amortizações',
#  'Despesas administrativas - Shopping',
#  'Custos dos serviços prestados e imóveis vendidos',
#  'Despesas administrativas - Propriedades',
#  'Outras receitas (despesas) operacionais']

# %%
#Organizar a tabela em um esquema de tabela dinamica, onde as datas sejam labels de coluna

dre = pd.pivot_table(dre, index=['DENOM_CIA','DS_CONTA'], columns=['DT_INI_EXERC', 'DT_FIM_EXERC'],values=['VL_AJUSTADO'])

# %%
dre
# Out:
#                                                                                      VL_AJUSTADO  \
# DT_INI_EXERC                                                                          2021-01-01
# DT_FIM_EXERC                                                                          2021-03-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores               8518.0
#                                        Atribuído a Sócios da Empresa Controladora        41877.0
#                                        Corrente                                         -11140.0
#                                        Custo dos Bens e/ou Serviços Vendidos            -71589.0
#                                        Despesas Financeiras                             -37746.0
# ...                                                                                          ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                  197196.0
#                                        Resultado Financeiro                             -14053.0
#                                        Resultado Líquido das Operações Continuadas       46321.0
#                                        Resultado Líquido de Operações Descontinuadas         0.0
#                                        Resultado de Equivalência Patrimonial             -2726.0
#
#                                                                                                  \
# DT_INI_EXERC
# DT_FIM_EXERC                                                                         2021-06-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             20110.0
#                                        Atribuído a Sócios da Empresa Controladora       98581.0
#                                        Corrente                                        -21337.0
#                                        Custo dos Bens e/ou Serviços Vendidos          -143404.0
#                                        Despesas Financeiras                            -78928.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 402818.0
#                                        Resultado Financeiro                            -27887.0
#                                        Resultado Líquido das Operações Continuadas     140114.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial            13858.0
#
#                                                                                                  \
# DT_INI_EXERC
# DT_FIM_EXERC                                                                         2021-09-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             26964.0
#                                        Atribuído a Sócios da Empresa Controladora      159166.0
#                                        Corrente                                        -39707.0
#                                        Custo dos Bens e/ou Serviços Vendidos          -221630.0
#                                        Despesas Financeiras                           -134999.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 655163.0
#                                        Resultado Financeiro                            -53051.0
#                                        Resultado Líquido das Operações Continuadas     239049.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial             6660.0
#
#                                                                                                  \
# DT_INI_EXERC                                                                         2021-04-01
# DT_FIM_EXERC                                                                         2021-06-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             11592.0
#                                        Atribuído a Sócios da Empresa Controladora       56705.0
#                                        Corrente                                        -10197.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -71816.0
#                                        Despesas Financeiras                            -41182.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 205622.0
#                                        Resultado Financeiro                            -13834.0
#                                        Resultado Líquido das Operações Continuadas      93793.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial            16584.0
#
#                                                                                                  \
# DT_INI_EXERC                                                                         2021-07-01
# DT_FIM_EXERC                                                                         2021-09-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores              6852.0
#                                        Atribuído a Sócios da Empresa Controladora       60584.0
#                                        Corrente                                        -18369.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -78226.0
#                                        Despesas Financeiras                            -56071.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 252345.0
#                                        Resultado Financeiro                            -25164.0
#                                        Resultado Líquido das Operações Continuadas      98935.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial            -7198.0
#
#                                                                                                  \
# DT_INI_EXERC                                                                         2022-01-01
# DT_FIM_EXERC                                                                         2022-03-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             13479.0
#                                        Atribuído a Sócios da Empresa Controladora       55947.0
#                                        Corrente                                        -28916.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -79203.0
#                                        Despesas Financeiras                            -83730.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 320486.0
#                                        Resultado Financeiro                            -53512.0
#                                        Resultado Líquido das Operações Continuadas     171606.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial             3979.0
#
#                                                                                                  \
# DT_INI_EXERC
# DT_FIM_EXERC                                                                         2022-06-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             27533.0
#                                        Atribuído a Sócios da Empresa Controladora       79511.0
#                                        Corrente                                        -53416.0
#                                        Custo dos Bens e/ou Serviços Vendidos          -156629.0
#                                        Despesas Financeiras                           -180909.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 668209.0
#                                        Resultado Financeiro                           -115090.0
#                                        Resultado Líquido das Operações Continuadas     344189.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial             6773.0
#
#                                                                                                  \
# DT_INI_EXERC
# DT_FIM_EXERC                                                                         2022-09-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             42613.0
#                                        Atribuído a Sócios da Empresa Controladora      172870.0
#                                        Corrente                                        -83895.0
#                                        Custo dos Bens e/ou Serviços Vendidos          -235952.0
#                                        Despesas Financeiras                           -270545.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                1031739.0
#                                        Resultado Financeiro                           -177806.0
#                                        Resultado Líquido das Operações Continuadas     530322.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial            10595.0
#
#                                                                                                  \
# DT_INI_EXERC                                                                         2022-04-01
# DT_FIM_EXERC                                                                         2022-06-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             14054.0
#                                        Atribuído a Sócios da Empresa Controladora       23564.0
#                                        Corrente                                        -24500.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -77426.0
#                                        Despesas Financeiras                            -97179.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 347723.0
#                                        Resultado Financeiro                            -61577.0
#                                        Resultado Líquido das Operações Continuadas     172583.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial             2794.0
#
#
# DT_INI_EXERC                                                                         2022-07-01
# DT_FIM_EXERC                                                                         2022-09-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             15080.0
#                                        Atribuído a Sócios da Empresa Controladora       93358.0
#                                        Corrente                                        -30481.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -79323.0
#                                        Despesas Financeiras                            -89636.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                 363530.0
#                                        Resultado Financeiro                            -62716.0
#                                        Resultado Líquido das Operações Continuadas     186133.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial             3822.0
#
# [182 rows x 10 columns]

# %%
dre.loc['BR PROPERTIES S.A.',:].loc['Resultado Bruto']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2021-01-01    2021-03-31       82348.0
#                            2021-06-30      160964.0
#                            2021-09-30      244462.0
#              2021-04-01    2021-06-30       78616.0
#              2021-07-01    2021-09-30       83498.0
#              2022-01-01    2022-03-31       83090.0
#                            2022-06-30      181134.0
#                            2022-09-30      265964.0
#              2022-04-01    2022-06-30       98044.0
#              2022-07-01    2022-09-30       84830.0
# Name: Resultado Bruto, dtype: float64

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Resultado Bruto']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2021-01-01    2021-03-31      204080.0
#                            2021-06-30      432887.0
#                            2021-09-30      701093.0
#              2021-04-01    2021-06-30      228811.0
#              2021-07-01    2021-09-30      268207.0
#              2022-01-01    2022-03-31      288784.0
#                            2022-06-30      585142.0
#                            2022-09-30      894120.0
#              2022-04-01    2022-06-30      296355.0
#              2022-07-01    2022-09-30      308978.0
# Name: Resultado Bruto, dtype: float64

# %% [markdown]
# ##4.3. Tabela Balanço Patrimonal Ativo e Passivo

# %%
#Preparando o BPA

bpa = pd.DataFrame()

for f in arquivos_xls:
  bpa_xls = pd.read_excel(f, sheet_name='BPA')
  bpa = bpa.append(bpa_xls)

# %%
bpa = pd.pivot_table(bpa, index=['DENOM_CIA','DS_CONTA'], columns=['DT_FIM_EXERC'],values=['VL_AJUSTADO'])

# %%
bpa
# Out:
#                                                                                           VL_AJUSTADO  \
# DT_FIM_EXERC                                                                               2021-12-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Aplicações Financeiras                               1231460.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...         0.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...    663453.5
#                                        Aplicações Financeiras Avaliadas ao Custo Amort...         0.0
#                                        Aplicações Financeiras de curto prazo                1231460.0
# ...                                                                                               ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Tributos Correntes a Recuperar                         43296.0
#                                        Tributos Diferidos                                     21478.0
#                                        Tributos a Recuperar                                   43296.0
#                                        Títulos Designados a Valor Justo                           0.0
#                                        Títulos para Negociação                               224670.0
#
#                                                                                                       \
# DT_FIM_EXERC                                                                              2022-03-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Aplicações Financeiras                              1781154.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...        0.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...   940150.5
#                                        Aplicações Financeiras Avaliadas ao Custo Amort...        0.0
#                                        Aplicações Financeiras de curto prazo               1781154.0
# ...                                                                                              ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Tributos Correntes a Recuperar                        67607.0
#                                        Tributos Diferidos                                    37590.0
#                                        Tributos a Recuperar                                  67607.0
#                                        Títulos Designados a Valor Justo                          0.0
#                                        Títulos para Negociação                              467341.0
#
#                                                                                                       \
# DT_FIM_EXERC                                                                              2022-06-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Aplicações Financeiras                              1442294.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...        0.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...   771104.0
#                                        Aplicações Financeiras Avaliadas ao Custo Amort...        0.0
#                                        Aplicações Financeiras de curto prazo               1442294.0
# ...                                                                                              ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Tributos Correntes a Recuperar                        70652.0
#                                        Tributos Diferidos                                    38317.0
#                                        Tributos a Recuperar                                  70652.0
#                                        Títulos Designados a Valor Justo                          0.0
#                                        Títulos para Negociação                              802816.0
#
#
# DT_FIM_EXERC                                                                              2022-09-30
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Aplicações Financeiras                              2614994.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...        0.0
#                                        Aplicações Financeiras Avaliadas a Valor Justo ...  1355815.0
#                                        Aplicações Financeiras Avaliadas ao Custo Amort...        0.0
#                                        Aplicações Financeiras de curto prazo               2614994.0
# ...                                                                                              ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Tributos Correntes a Recuperar                        78373.0
#                                        Tributos Diferidos                                    34139.0
#                                        Tributos a Recuperar                                  78373.0
#                                        Títulos Designados a Valor Justo                          0.0
#                                        Títulos para Negociação                             1101546.0
#
# [260 rows x 4 columns]

# %%
bpa.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Ativo Total']
# Out:
#              DT_FIM_EXERC
# VL_AJUSTADO  2021-12-31      19485787.0
#              2022-03-31      19521061.0
#              2022-06-30      18379356.0
#              2022-09-30      18347867.0
# Name: Ativo Total, dtype: float64

# %%
bpp = pd.DataFrame()

for f in arquivos_xls:
  bpp_xls = pd.read_excel(f, sheet_name='BPP')
  bpp = bpp.append(bpp_xls)

bpp = pd.pivot_table(bpp, index=['DENOM_CIA','DS_CONTA', 'CD_CONTA'], columns=['DT_REFER','DT_FIM_EXERC'],values=['VL_AJUSTADO'])

bpp.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Passivo Total']
# Out:
#              VL_AJUSTADO                                                  \
# DT_REFER      2022-03-31              2022-06-30              2022-09-30
# DT_FIM_EXERC  2021-12-31  2022-03-31  2021-12-31  2022-06-30  2021-12-31
# CD_CONTA
# 2             19485787.0  19521061.0  19485787.0  18379356.0  19485787.0
#
#
# DT_REFER
# DT_FIM_EXERC  2022-09-30
# CD_CONTA
# 2             18347867.0

# %% [markdown]
# #5. Indicadores Fundamentalistas

# %% [markdown]
# ##5.1. Margens

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Resultado Bruto']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2021-01-01    2021-03-31      204080.0
#                            2021-06-30      432887.0
#                            2021-09-30      701093.0
#              2021-04-01    2021-06-30      228811.0
#              2021-07-01    2021-09-30      268207.0
#              2022-01-01    2022-03-31      288784.0
#                            2022-06-30      585142.0
#                            2022-09-30      894120.0
#              2022-04-01    2022-06-30      296355.0
#              2022-07-01    2022-09-30      308978.0
# Name: Resultado Bruto, dtype: float64

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Resultado Bruto'].iloc[-1]
# Out:
# 308978.0

# %%
for i in range(0,n_empresas):
  calculo_margem = ((dre.loc[lista_de_empresas[i],:].loc['Resultado Bruto'].iloc[-1])/(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1]))
  print(f'A margem bruta de {lista_de_empresas[i]} é  {calculo_margem}')
# Out:
# A margem bruta de IGUATEMI EMPRESA DE SHOPPING CENTERS S.A é  0.5838164123825094
# A margem bruta de BR MALLS PARTICIPACOES S.A. é  0.8869095460077617
# A margem bruta de ALIANSCE SONAE SHOPPING CENTERS S.A. é  0.7094874471241004
# A margem bruta de BR PROPERTIES S.A. é  1.0
# A margem bruta de MULTIPLAN - EMPREEND IMOBILIARIOS S.A. é  0.8096057868117527

# %%
import plotly.graph_objects as go

# %%
#Margem Bruta
margem_bruta_shopping = pd.DataFrame()
for i in range(0,n_empresas):
  calculo_margem = pd.Series((dre.loc[lista_de_empresas[i],:].loc['Resultado Bruto'].iloc[-1])/(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1]))
  margem_bruta_shopping = pd.concat([margem_bruta_shopping,calculo_margem], axis=1)
margem_bruta_shopping.columns = lista_de_empresas
fig = go.Figure(go.Bar(x=margem_bruta_shopping.iloc[-1],y=tickers,orientation='h'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2e3b770b-d534-4edb-8826-2195d97bf739" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3b770b-d534-4edb-8826-2195d97bf739")) {                    Plotly.newPlot(                        "2e3b770b-d534-4edb-8826-2195d97bf739",                        [{"orientation":"h","x":[0.5838164123825094,0.8869095460077617,0.7094874471241004,1.0,0.8096057868117527],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type" ...

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Lucro/Prejuízo Consolidado do Período'].iloc[-1]
# Out:
# 138639.0

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Resultado Bruto'].iloc[-1]
# Out:
# 308978.0

# %%
def margem_liquida():
  margem_liq_shopping = pd.DataFrame()
  for i in range(0,n_empresas):
    calculo_margem_liq = pd.Series((dre.loc[lista_de_empresas[i],:].loc['Lucro/Prejuízo Consolidado do Período'].iloc[-1])/(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1]))
    margem_liq_shopping = pd.concat([margem_liq_shopping,calculo_margem_liq], axis=1)
  margem_liq_shopping.columns = lista_de_empresas
  fig = go.Figure(go.Bar(x=margem_liq_shopping.iloc[-1],y=tickers,orientation='h'))
  fig.update_layout(title_text='Margem Líquida')
  fig.show()

# %%
margem_liquida()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cfd364ae-af4f-46a8-b2f2-74bf20a17f59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd364ae-af4f-46a8-b2f2-74bf20a17f59")) {                    Plotly.newPlot(                        "cfd364ae-af4f-46a8-b2f2-74bf20a17f59",                        [{"orientation":"h","x":[0.26108985878811725,0.3979579534755551,0.3971433280228534,0.594471295532241,0.4145307235073638],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ##5.2. Dívida Bruta/Patrimônio Líquido

# %%
#Fazer um ajuste no patrimônio líquido para remover a conta Participação dos Acionistas Não Controladores
pl_ajustado = pd.DataFrame()

for i in range(0,n_empresas):
  pl_ajd = pd.Series(bpp.loc[lista_de_empresas[i],:].loc['Patrimônio Líquido Consolidado'].iloc[-1,3] - bpp.loc[lista_de_empresas[i],:].loc['Participação dos Acionistas Não Controladores'].iloc[-1,3] )     
  pl_ajustado = pd.concat([pl_ajustado,pl_ajd], axis=1)
pl_ajustado.columns = lista_de_empresas

# %%
pl_ajustado
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                 3287451.0                   10976673.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                             6708840.0           5559395.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                               6479048.0

# %%
divida_bruta_pl_df = pd.DataFrame()

for i in range(0,n_empresas):
  dbpl = pd.Series((bpp.loc[lista_de_empresas[i],:].loc['Empréstimos e Financiamentos'].iloc[-2,3] + bpp.loc[lista_de_empresas[i],:].loc['Empréstimos e Financiamentos'].iloc[0,3]))
  divida_bruta_pl_df = pd.concat([divida_bruta_pl_df,dbpl], axis=1)
divida_bruta_pl_df.columns = lista_de_empresas
#divida_bruta_pl_df = divida_bruta_pl_df/pl_ajustado

# %%
divida_bruta_pl_df
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                 3158275.0                    3536219.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                                   0.0           2928025.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                               2994646.0

# %%
divida_bruta_pl = divida_bruta_pl_df/pl_ajustado
fig = go.Figure(go.Bar(x=divida_bruta_pl.iloc[-1],y=tickers,orientation='h'))
fig.update_layout(title_text='Div Bruta/PL')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b0978ae5-ded7-4f0d-9193-acf45c09ae2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0978ae5-ded7-4f0d-9193-acf45c09ae2a")) {                    Plotly.newPlot(                        "b0978ae5-ded7-4f0d-9193-acf45c09ae2a",                        [{"orientation":"h","x":[0.9607063344822478,0.3221576337383832,0.0,0.5266805110987797,0.46220463253243377],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type ...

# %% [markdown]
# ##5.3. Disponibilidades

# %% [markdown]
# ###5.3.1. Disponibilidades

# %%
caixa_ajustado = pd.DataFrame()

for i in range(0,n_empresas):
  caixa_aj = pd.Series(bpa.loc[lista_de_empresas[i],:].loc['Caixa e Equivalentes de Caixa'].iloc[-1,] + bpa.loc[lista_de_empresas[i],:].loc['Aplicações Financeiras'].iloc[-1,])     
  caixa_ajustado = pd.concat([caixa_ajustado,caixa_aj], axis=1)
caixa_ajustado.columns = lista_de_empresas

# %%
caixa_ajustado
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                 1439133.0                    1187240.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                             2633946.0           1545500.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                               1155008.0

# %%
fig = go.Figure(go.Bar(x=caixa_ajustado.iloc[-1],y=tickers,orientation='h'))
fig.update_layout(title_text='Disponibilidades')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a69f4caf-aa20-48ea-b3ae-5da280f1bee1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a69f4caf-aa20-48ea-b3ae-5da280f1bee1")) {                    Plotly.newPlot(                        "a69f4caf-aa20-48ea-b3ae-5da280f1bee1",                        [{"orientation":"h","x":[1439133.0,1187240.0,2633946.0,1545500.0,1155008.0],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo ...

# %% [markdown]
# ###5.3.2. Liquidez Corrente

# %%
liquidez_corrente = pd.DataFrame()

for i in range(0,n_empresas):
  liq_corrente = pd.Series((bpa.loc[lista_de_empresas[i],:].loc['Ativo Circulante'].iloc[-1,]) /( bpp.loc[lista_de_empresas[i],:].loc['Passivo Circulante'].iloc[-1,3]))     
  liquidez_corrente = pd.concat([liquidez_corrente,liq_corrente], axis=1)
liquidez_corrente.columns = lista_de_empresas

# %%
liquidez_corrente
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  1.927867                     2.123702
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              3.870501            3.738467
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                1.180463

# %% [markdown]
# ##5.3. EBIT

# %%
#EBIT

ebit_ajustado = pd.DataFrame()

for i in range(0,n_empresas):
  ebit_ajustado_ = pd.Series(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])
  ebit_ajustado = pd.concat([ebit_ajustado,ebit_ajustado_], axis=1)
ebit_ajustado.columns = lista_de_empresas
fig = go.Figure(go.Bar(x=ebit_ajustado.iloc[-1],y=tickers,orientation='h'))
fig.update_layout(title_text='Resultado operacional EBIT')
fig.show()
ebit_ajustado
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6566e13c-d8e2-4626-a21b-097609ec94be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6566e13c-d8e2-4626-a21b-097609ec94be")) {                    Plotly.newPlot(                        "6566e13c-d8e2-4626-a21b-097609ec94be",                        [{"orientation":"h","x":[111839.0,224828.0,141217.0,38414.0,280979.0],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"m ...
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  111839.0                     224828.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              141217.0             38414.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                280979.0

# %%
ebit_ajustado
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  111839.0                     224828.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              141217.0             38414.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                280979.0

# %%
#Margem operacional

margem_operacional = pd.DataFrame()

for i in range(0,n_empresas):
  margem_operacional_ = pd.Series((dre.loc[lista_de_empresas[i],:].loc['Resultado Bruto'].iloc[-1])/(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,]))
  margem_operacional = pd.concat([margem_operacional,margem_operacional_], axis=1)
margem_operacional.columns = lista_de_empresas
fig = go.Figure(go.Bar(x=margem_operacional.iloc[-1],y=tickers,orientation='h'))
fig.update_layout(title_text='Margem Operacional')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c9c91d85-b1e9-485f-9870-140aa7f18f45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9c91d85-b1e9-485f-9870-140aa7f18f45")) {                    Plotly.newPlot(                        "c9c91d85-b1e9-485f-9870-140aa7f18f45",                        [{"orientation":"h","x":[1.2868140809556594,1.3742861209457897,1.371803678027433,2.208309470505545,1.2937977571277568],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks ...

# %% [markdown]
# ##5.4. Ebitda/Div Bruta

# %%
#Ebitda/Divida Bruta

ebit_div_bruta = pd.DataFrame()

for i in range(0,n_empresas):
  ebit_div_ajustado_ = pd.Series((dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])/
                             (bpp.loc[lista_de_empresas[i],:].loc['Empréstimos e Financiamentos'].iloc[-2,3] + bpp.loc[lista_de_empresas[i],:].loc['Empréstimos e Financiamentos'].iloc[0,3]))
  ebit_div_bruta = pd.concat([ebit_div_bruta, ebit_div_ajustado_], axis=1)
ebit_div_bruta.columns = lista_de_empresas
# Out:
# <ipython-input-97-e2be4dfcb852>:6: RuntimeWarning:
#
# divide by zero encountered in double_scalars

# %%
ebit_div_bruta
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  0.035411                     0.063579
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                                   inf            0.013119
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                0.093827

# %%
fig = go.Figure(go.Bar(
    x=ebit_div_bruta.iloc[-1],
    y=tickers,
    orientation='h'
))
fig.update_layout(title_text='EBIT/Divida Bruta')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c2303457-bf19-46e2-a78d-5346f7112db9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2303457-bf19-46e2-a78d-5346f7112db9")) {                    Plotly.newPlot(                        "c2303457-bf19-46e2-a78d-5346f7112db9",                        [{"orientation":"h","x":[0.03541141920827034,0.06357864148119785,null,0.013119423502190043,0.09382711679443914],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}, ...

# %% [markdown]
# ##5.5. Return on Equity - ROE

# %%
#ROE E ROIC 
demonstrativos = ['DFC_MD', 'DFC_MI','BPA', 'DRE', 'BPP']

lista_listas = []

a = 0

for j in empresas:

  c = 0

  lista_df = []

  for k in demonstrativos:

    link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/itr_cia_aberta_2020.zip'

    r = requests.get(link)

    zf = zipfile.ZipFile(io.BytesIO(r.content))

    arquivo = 'itr_cia_aberta_' + str(k) + '_con_2021.csv'

    zf = zf.open(arquivo)

    lines = zf.readlines()

    lines = [i.strip().decode('ISO-8859-1') for i in lines]

    lines = [i.split(';') for i in lines]

    c += 1 

    df = pd.DataFrame(lines[1:], columns = lines[0])

    df['VL_AJUSTADO'] = pd.to_numeric(df['VL_CONTA'])

    filtro = df[df['CD_CVM']== '0' + str(j)]

    lista_df.append(filtro)

    print(f'Trabalhando com a empresa {j} e sua demonstração {k}. As dimensões são {filtro.shape} ')

  lista_listas.append(lista_df)


  writer = pd.ExcelWriter(f'Demonstrativos Empresa {str(j)}.xlsx', engine='xlsxwriter')

  
  lista_listas[a][0].to_excel(writer, sheet_name='DFC_MD',encoding= 'ISO-8859-1')
  lista_listas[a][1].to_excel(writer, sheet_name='DFC_MI',encoding= 'ISO-8859-1')
  lista_listas[a][2].to_excel(writer, sheet_name='BPA',encoding= 'ISO-8859-1')
  lista_listas[a][3].to_excel(writer, sheet_name='DRE',encoding= 'ISO-8859-1')
  lista_listas[a][4].to_excel(writer, sheet_name='BPP',encoding= 'ISO-8859-1')

  a += 1

  print(f'Arquivo excel com os demonstrativos da empresa {j} já exportado. \n')

  
  writer.save()


print("O tempo de execução desse programa foi de %s segundos ---" % (time.time() - start_time))
# Out:
# Trabalhando com a empresa 22357 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e sua demonstração DFC_MI. As dimensões são (422, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPA. As dimensões são (372, 15)
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (300, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPP. As dimensões são (654, 15)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 22357 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 22357 e sua demonstração DFC_MI. As dimensões são (422, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPA. As dimensões são (372, 15)
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (300, 16)
# Trabalhando com a empresa 22357 e sua demonstração BPP. As dimensões são (654, 15)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 19909 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19909 e sua demonstração DFC_MI. As dimensões são (434, 16)
# Trabalhando com a empresa 19909 e sua demonstração BPA. As dimensões são (392, 15)
# Trabalhando com a empresa 19909 e sua demonstração DRE. As dimensões são (336, 16)
# Trabalhando com a empresa 19909 e sua demonstração BPP. As dimensões são (704, 15)
# Arquivo excel com os demonstrativos da empresa 19909 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19925 e sua demonstração DFC_MI. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPA. As dimensões são (384, 15)
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPP. As dimensões são (692, 15)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 19925 e sua demonstração DFC_MI. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPA. As dimensões são (384, 15)
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (386, 16)
# Trabalhando com a empresa 19925 e sua demonstração BPP. As dimensões são (692, 15)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 20494 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20494 e sua demonstração DFC_MI. As dimensões são (308, 16)
# Trabalhando com a empresa 20494 e sua demonstração BPA. As dimensões são (408, 15)
# Trabalhando com a empresa 20494 e sua demonstração DRE. As dimensões são (300, 16)
# Trabalhando com a empresa 20494 e sua demonstração BPP. As dimensões são (666, 15)
# Arquivo excel com os demonstrativos da empresa 20494 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e sua demonstração DFC_MI. As dimensões são (342, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPA. As dimensões são (378, 15)
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (374, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPP. As dimensões são (698, 15)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DFC_MD. As dimensões são (0, 16)
# Trabalhando com a empresa 20982 e sua demonstração DFC_MI. As dimensões são (342, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPA. As dimensões são (378, 15)
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (374, 16)
# Trabalhando com a empresa 20982 e sua demonstração BPP. As dimensões são (698, 15)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# O tempo de execução desse programa foi de 351.89042925834656 segundos ---

# %%
dre2 = pd.DataFrame()


for f in arquivos_xls:
  dre2_xls = pd.read_excel(f, sheet_name='DRE')
  dre2 = dre2.append(dre2_xls)

# %%
dre2 = pd.pivot_table(dre2, index=['DENOM_CIA','DS_CONTA'], columns=['DT_INI_EXERC', 'DT_FIM_EXERC'],values=['VL_AJUSTADO'])

# %%
dre2.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Receita de Venda de Bens e/ou Serviços']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2020-01-01    2020-03-31      283760.0
#                            2020-06-30      462491.0
#                            2020-09-30      660843.0
#              2020-04-01    2020-06-30      178729.0
#              2020-07-01    2020-09-30      198352.0
#              2021-01-01    2021-03-31      230691.0
#                            2021-06-30      481517.0
#                            2021-09-30      773257.0
#              2021-04-01    2021-06-30      250829.0
#              2021-07-01    2021-09-30      291742.0
# Name: Receita de Venda de Bens e/ou Serviços, dtype: float64

# %%
#PEGANDO DADOS ANUAIS CVM, O REPOSITÓRIO É DEMONSTRAÇÕES FINANCEIRAS PADRONIZADAS

#Remover demais demonstrações,manter somente DRE
demonstrativos = ['DRE']

lista_listas = []

a = 0


#Modificar o link com o link direto do zip da cvm
for j in empresas:

  c = 0

  lista_df = []

  for k in demonstrativos:

    link = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/dfp_cia_aberta_2020.zip'

    r = requests.get(link)

    zf = zipfile.ZipFile(io.BytesIO(r.content))

    arquivo = 'dfp_cia_aberta_' + str(k) + '_con_2021.csv'

    zf = zf.open(arquivo)

    lines = zf.readlines()

    lines = [i.strip().decode('ISO-8859-1') for i in lines]

    lines = [i.split(';') for i in lines]

    c += 1 

    df = pd.DataFrame(lines[1:], columns = lines[0])

    df['VL_AJUSTADO'] = pd.to_numeric(df['VL_CONTA'])

    filtro = df[df['CD_CVM']== '0' + str(j)]

    lista_df.append(filtro)

    print(f'Trabalhando com a empresa {j} e sua demonstração {k}. As dimensões são {filtro.shape} ')

  lista_listas.append(lista_df)

  # Manter
  writer = pd.ExcelWriter(f'Demonstrativos Empresa {str(j)}.xlsx', engine='xlsxwriter')

  # Deixar apenas um repositório
  lista_listas[a][0].to_excel(writer, sheet_name='DRE',encoding= 'ISO-8859-1')
  

  a += 1

  print(f'Arquivo excel com os demonstrativos da empresa {j} já exportado. \n')

  
  writer.save()


print("O tempo de execução desse programa foi de %s segundos ---" % (time.time() - start_time))
# Out:
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (60, 16)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 22357 e sua demonstração DRE. As dimensões são (60, 16)
# Arquivo excel com os demonstrativos da empresa 22357 já exportado.
#
# Trabalhando com a empresa 19909 e sua demonstração DRE. As dimensões são (68, 16)
# Arquivo excel com os demonstrativos da empresa 19909 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (78, 16)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 19925 e sua demonstração DRE. As dimensões são (78, 16)
# Arquivo excel com os demonstrativos da empresa 19925 já exportado.
#
# Trabalhando com a empresa 20494 e sua demonstração DRE. As dimensões são (60, 16)
# Arquivo excel com os demonstrativos da empresa 20494 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (76, 16)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# Trabalhando com a empresa 20982 e sua demonstração DRE. As dimensões são (76, 16)
# Arquivo excel com os demonstrativos da empresa 20982 já exportado.
#
# O tempo de execução desse programa foi de 369.86968779563904 segundos ---

# %%
dre3 = pd.DataFrame()


for f in arquivos_xls:
  dre3_xls = pd.read_excel(f, sheet_name='DRE')
  dre3 = dre3.append(dre3_xls)

# %%
dre3 = pd.pivot_table(dre3, index=['DENOM_CIA','DS_CONTA'], columns=['DT_INI_EXERC', 'DT_FIM_EXERC'],values=['VL_AJUSTADO'])

# %%
dre3
# Out:
#                                                                                      VL_AJUSTADO  \
# DT_INI_EXERC                                                                          2020-01-01
# DT_FIM_EXERC                                                                          2020-12-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores              33402.0
#                                        Atribuído a Sócios da Empresa Controladora       169071.0
#                                        Corrente                                         -30254.0
#                                        Custo dos Bens e/ou Serviços Vendidos           -269549.0
#                                        Despesas Financeiras                            -154062.0
# ...                                                                                          ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                  806796.0
#                                        Resultado Financeiro                             -76120.0
#                                        Resultado Líquido das Operações Continuadas      963978.0
#                                        Resultado Líquido de Operações Descontinuadas         0.0
#                                        Resultado de Equivalência Patrimonial             -5221.0
#
#
# DT_INI_EXERC                                                                         2021-01-01
# DT_FIM_EXERC                                                                         2021-12-31
# DENOM_CIA                              DS_CONTA
# ALIANSCE SONAE SHOPPING CENTERS S.A.   Atribuído a Sócios Não Controladores             43537.0
#                                        Atribuído a Sócios da Empresa Controladora      274868.0
#                                        Corrente                                        -61379.0
#                                        Custo dos Bens e/ou Serviços Vendidos          -300793.0
#                                        Despesas Financeiras                           -216729.0
# ...                                                                                         ...
# MULTIPLAN - EMPREEND IMOBILIARIOS S.A. Resultado Bruto                                1017012.0
#                                        Resultado Financeiro                           -114155.0
#                                        Resultado Líquido das Operações Continuadas     452698.0
#                                        Resultado Líquido de Operações Descontinuadas        0.0
#                                        Resultado de Equivalência Patrimonial           -10880.0
#
# [165 rows x 2 columns]

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1]
# Out:
# 127513.0

# %%
dre.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2021-01-01    2021-03-31       56538.0
#                            2021-06-30      -56460.0
#                            2021-09-30         689.0
#              2021-04-01    2021-06-30     -112997.0
#              2021-07-01    2021-09-30       57149.0
#              2022-01-01    2022-03-31       72104.0
#                            2022-06-30      228387.0
#                            2022-09-30      355900.0
#              2022-04-01    2022-06-30      156283.0
#              2022-07-01    2022-09-30      127513.0
# Name: Atribuído a Sócios da Empresa Controladora, dtype: float64

# %%
dre2.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2020-01-01    2020-03-31      118542.0
#                            2020-06-30     -501152.0
#                            2020-09-30     -493342.0
#              2020-04-01    2020-06-30     -619694.0
#              2020-07-01    2020-09-30        7810.0
#              2021-01-01    2021-03-31       56538.0
#                            2021-06-30      -56460.0
#                            2021-09-30         689.0
#              2021-04-01    2021-06-30     -112997.0
#              2021-07-01    2021-09-30       57149.0
# Name: Atribuído a Sócios da Empresa Controladora, dtype: float64

# %%
dre3.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora']
# Out:
#              DT_INI_EXERC  DT_FIM_EXERC
# VL_AJUSTADO  2020-01-01    2020-12-31     -293879.0
#              2021-01-01    2021-12-31      186965.0
# Name: Atribuído a Sócios da Empresa Controladora, dtype: float64

# %%
ll_Q4_brmalls = dre3.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1] - (
    dre2.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-5]+
    dre2.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-2]+
    dre2.loc['BR MALLS PARTICIPACOES S.A.',:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1]
)

# %%
ll_Q4_brmalls
# Out:
# 186275.0

# %%
Q320 = pd.DataFrame()

for i in range(0,n_empresas):
  Q320_ = pd.Series(dre2.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1])
  Q320 = pd.concat([Q320,Q320_], axis=1)
Q320.columns = lista_de_empresas
Q320
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  -58747.0                      57149.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                               60584.0                 0.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                 99404.0

# %%
Q420 = pd.DataFrame()

for i in range(0,n_empresas):
  Q420_ = pd.Series(dre3.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1] - (
    dre2.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-5]+
    dre2.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-2]+
    dre2.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1]
))
  Q420 = pd.concat([Q420,Q420_], axis=1)
Q420.columns = lista_de_empresas
Q420
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                   81963.0                     186275.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              115702.0             -9176.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                213610.0

# %%
Q221 = pd.DataFrame()

for i in range(0,n_empresas):
  Q221_ = pd.Series(dre.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-1])
  Q221 = pd.concat([Q221,Q221_], axis=1)
Q221.columns = lista_de_empresas
Q221
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                   63024.0                     127513.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                               93358.0                 0.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                186098.0

# %%
Q121 = pd.DataFrame()

for i in range(0,n_empresas):
  Q121_ = pd.Series(dre.loc[lista_de_empresas[i],:].loc['Atribuído a Sócios da Empresa Controladora'].iloc[-3])
  Q121 = pd.concat([Q121,Q121_], axis=1)
Q121.columns = lista_de_empresas
Q121
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  -56141.0                     355900.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              172870.0                 0.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                530228.0

# %%
#ROE
#Junta os lucros líquidos dos últimos 4 trimestre e divide pelo PL ajustado

roe = ((Q320+Q420+Q121+Q221)/pl_ajustado)*100
roe
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  0.915573                     6.621651
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              6.595984           -0.165054
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                               15.887211

# %%
fig = go.Figure(go.Bar(
    x=roe.iloc[-1],
    y=tickers,
    orientation='h',text=roe.iloc[-1]
))
fig.update_layout(title_text='Return On Equity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="84a699a6-0dba-49d3-b70a-dd907c970da2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84a699a6-0dba-49d3-b70a-dd907c970da2")) {                    Plotly.newPlot(                        "84a699a6-0dba-49d3-b70a-dd907c970da2",                        [{"orientation":"h","text":[0.9155725819183314,6.6216512052422445,6.595983806440457,-0.16505393122812823,15.887210590197821],"x":[0.9155725819183314,6.6216512052422445,6.595983806440457,-0.16505393122812823,15.887210590197821],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outli ...

# %% [markdown]
# ##5.6. EBIT/Ativo

# %%
#Roic
receita_liq_Q420 = pd.DataFrame()

for i in range(0,n_empresas):
  receita_liq_Q420_ = pd.Series(dre3.loc[lista_de_empresas[i],:].loc['Resultado Antes do Resultado Financeiro e dos Tributos'].iloc[-1] - (
    dre2.loc[lista_de_empresas[i],:].loc['Resultado Antes do Resultado Financeiro e dos Tributos'].iloc[-5]+
    dre2.loc[lista_de_empresas[i],:].loc['Resultado Antes do Resultado Financeiro e dos Tributos'].iloc[-2]+
    dre2.loc[lista_de_empresas[i],:].loc['Resultado Antes do Resultado Financeiro e dos Tributos'].iloc[-1]
))
  receita_liq_Q420 = pd.concat([receita_liq_Q420,receita_liq_Q420_], axis=1)
receita_liq_Q420.columns = lista_de_empresas
receita_liq_Q420
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  143655.0                     374603.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              190825.0            -18138.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                226059.0

# %%
receita_liq_Q320 = pd.DataFrame()


for i in range(0,n_empresas):
  receita_liq_Q320_ = pd.Series(dre2.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])
  receita_liq_Q320 = pd.concat([receita_liq_Q320,receita_liq_Q320_], axis=1)
receita_liq_Q320.columns = lista_de_empresas
receita_liq_Q320
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                   88081.0                     178641.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              116956.0             55321.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                180350.0

# %%
receita_liq_Q221 = pd.DataFrame()


for i in range(0,n_empresas):
  receita_liq_Q221_ = pd.Series(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])
  receita_liq_Q221 = pd.concat([receita_liq_Q221,receita_liq_Q221_], axis=1)
receita_liq_Q221.columns = lista_de_empresas
receita_liq_Q221
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  111839.0                     224828.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              141217.0             38414.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                280979.0

# %%
receita_liq_Q121 = pd.DataFrame()


for i in range(0,n_empresas):
  receita_liq_Q121_ = pd.Series(dre.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-3,]+
                             dre.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-3,]+ 
                             dre.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-3,]+
                             dre.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-3,])
  receita_liq_Q121 = pd.concat([receita_liq_Q121,receita_liq_Q121_], axis=1)
receita_liq_Q121.columns = lista_de_empresas
receita_liq_Q121
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  326157.0                     660079.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              409568.0            156610.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                784061.0

# %%
receita_liq_Q420 = pd.DataFrame()


for i in range(0,n_empresas):
  receita_liq_Q420_ = pd.Series((dre3.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre3.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre3.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre3.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])-
                             ((dre2.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-1,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-1,]+ 
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-1,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-1,])+
                             (dre2.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-2,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-2,]+ 
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-2,]+
                             (dre2.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-5,]))+
                             (dre2.loc[lista_de_empresas[i],:].loc['Receita de Venda de Bens e/ou Serviços'].iloc[-5,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Custo dos Bens e/ou Serviços Vendidos'].iloc[-5,]+ 
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas com Vendas'].iloc[-5,]+
                             dre2.loc[lista_de_empresas[i],:].loc['Despesas Gerais e Administrativas'].iloc[-5,]))
                             )
  receita_liq_Q420 = pd.concat([receita_liq_Q420,receita_liq_Q420_], axis=1)
receita_liq_Q420.columns = lista_de_empresas
receita_liq_Q420
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  165478.0                     205995.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              164946.0             43888.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                                295960.0

# %%
ebit_ano = receita_liq_Q121+receita_liq_Q221+receita_liq_Q420+receita_liq_Q320
ebit_ano
# Out:
#    IGUATEMI EMPRESA DE SHOPPING CENTERS S.A  BR MALLS PARTICIPACOES S.A.  \
# 0                                  691555.0                    1269543.0
#
#    ALIANSCE SONAE SHOPPING CENTERS S.A.  BR PROPERTIES S.A.  \
# 0                              832687.0            294233.0
#
#    MULTIPLAN - EMPREEND IMOBILIARIOS S.A.
# 0                               1541350.0

# %%
#EBIT/ATIVO

ebit_ativo = pd.DataFrame()
for i in range(0,n_empresas):
  ebit_ativo_ = pd.Series(bpa.loc[lista_de_empresas[i],:].loc['Ativo Total'].iloc[-1])
  ebit_ativo = pd.concat([ebit_ativo,ebit_ativo_], axis=1)
ebit_ativo.columns = lista_de_empresas
ebit_ativo = ebit_ano/ebit_ativo
ebit_ativo

fig = go.Figure(go.Bar(
    x=ebit_ativo.iloc[-1],
    y=tickers,
    orientation='h'
))
fig.update_layout(title_text='EBIT/ATIVO')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16191768-ca79-4b60-88c9-a73fc43a5250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16191768-ca79-4b60-88c9-a73fc43a5250")) {                    Plotly.newPlot(                        "16191768-ca79-4b60-88c9-a73fc43a5250",                        [{"orientation":"h","x":[0.10462319055231659,0.0691929476052993,0.06753301460583404,0.045149622294107745,0.14036957354824703],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0 ...

# %%
bpa.loc[lista_de_empresas[i],:].loc['Caixa e Equivalentes de Caixa'].iloc[-1,] + bpa.loc[lista_de_empresas[i],:].loc['Aplicações Financeiras'].iloc[-1,]
# Out:
# 1155008.0

# %% [markdown]
# ##5.7. ROIC

# %%
roic = ebit_ano/(pl_ajustado+divida_bruta_pl_df+caixa_ajustado)
roic

fig = go.Figure(go.Bar(
    x=roic.iloc[-1],
    y=tickers,
    orientation='h'
))
fig.update_layout(title_text='ROIC')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="37e83df6-44c7-42c8-ac67-c980d6f97d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37e83df6-44c7-42c8-ac67-c980d6f97d97")) {                    Plotly.newPlot(                        "37e83df6-44c7-42c8-ac67-c980d6f97d97",                        [{"orientation":"h","x":[0.08912619854505925,0.14501770771256922,0.08086193160668968,0.029326756318200482,0.08770670471088957],"y":["BRML3","ALSO3","BRPR3","IGTA3","MULT3"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth": ...

# %% [markdown]
# #6. Equity e Preço
#
# Indicadores fundamentalistas ligados ao preço e valor do ativo

# %%
#Coletar dados de preços dos shoppings

shoppings_preços = pd.DataFrame()

for i in tickers:
  
  df = investpy.get_stock_historical_data(stock=i, country='Brazil', from_date='31/08/2021', to_date='08/09/2021').Close
  df.rename(i, inplace=True)
  df.columns = [i]
  shoppings_preços = pd.concat([shoppings_preços,df], axis=1)
  shoppings_preços.index.name="Date"

shoppings_preços.columns=lista_de_empresas
shoppings_preços
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-131-212d2afbffb3> in <module>
#       5 for i in tickers:
#       6
# ----> 7   df = investpy.get_stock_historical_data(stock=i, country='Brazil', from_date='31/08/2021', to_date='08/09/2021').Close
#       8   df.rename(i, inplace=True)
#       9   df.columns = [i]
#
# /usr/local/lib/python3.8/dist-packages/investpy/stocks.py in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     662
#     663         if req.status_code != 200:
# --> 664             raise ConnectionError(
#     665                 "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666             )
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
#Número de açoes da empresa

n_acoes = pd.DataFrame()

for i in tickers:
  df_ =investpy.get_stock_information(i, country='Brazil')['Shares Outstanding']
  df_.rename(i,inplace=True)
  df_.columns = [i]
  n_acoes = pd.concat([n_acoes,df_], axis=1)
  
n_acoes.columns=lista_de_empresas
n_acoes

# %%
n_acoes = n_acoes/1000
n_acoes

# %% [markdown]
# ##6.1. Valor de Mercado

# %%
#MarketCap das ações

marketcap = n_acoes*shoppings_preços.iloc[-1]
marketcap

# %%
fig = go.Figure(go.Bar(
    x=marketcap.iloc[-1],
    y=tickers,
    orientation='h',text=marketcap.iloc[-1]
))
fig.update_layout(title_text='Marketcap')
fig.show()

# %% [markdown]
# ##6.2. Valor da Firma

# %%
#Enterprise Value

ev = marketcap + (divida_bruta_pl_df-caixa_ajustado)

# %%
(divida_bruta_pl_df-caixa_ajustado)

# %%
ev

fig = go.Figure(go.Bar(
    x=ev.iloc[-1],
    y=tickers,
    orientation='h'
))
fig.update_layout(title_text='Enterprise Value')
fig.show()

# %% [markdown]
# ##6.3. Valor Patrimonial da Ação

# %%
#Valor Patrimonial da Ação

vpa = (pl_ajustado)/n_acoes

# %%
vpa

# %%
fig = go.Figure(go.Bar(
    x=vpa.iloc[-1],
    y=tickers,
    orientation='h'
))
fig.update_layout(title_text='Valor Patrimonial da Ação')
fig.show()

# %%
type(pl_ajustado.iloc[-1,-1])

# %% [markdown]
# ##6.4. Lucro por Ação e P/L

# %%
#LPA

lpa = (Q320+Q420+Q121+Q221)/n_acoes
lpa

# %%
#P/L

pl = shoppings_preços.iloc[-1]/lpa
pl

# %%
fig = go.Figure(go.Bar(
    x=pl.iloc[-1],
    y=tickers,
    orientation='h',
))
fig.update_layout(title_text='Preço/Lucro')
fig.show()

# %%
#P/VPA
pvpa = shoppings_preços.iloc[-1]/vpa
pvpa

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Bar(
    x=pvpa.iloc[-1],
    y=tickers,
    orientation='h',text=pvpa.iloc[-1]
))
fig.update_layout(title_text='P/VPA')
fig.show()

# %%
fig = ff.create_table(lpa, height_constant=50)
trace1=go.Bar(x=tickers, y=pl.iloc[-1],marker=dict(color='#0099ff'), name='P/L',xaxis='x2' ,yaxis='y2')
fig.add_traces([trace1])
# initialize xaxis2 and yaxis2
fig['layout']['xaxis2'] = {}
fig['layout']['yaxis2'] = {}

# Edit layout for subplots
fig.layout.yaxis.update({'domain': [0, .45]})
fig.layout.yaxis2.update({'domain': [.5, 1]})
fig.layout.xaxis2.update({'anchor': 'y2'})
fig.layout.yaxis2.update({'title': 'Goals'})

fig.layout.margin.update({'t':75, 'l':50})
fig.layout.update({'title': 'Analitcs'})

# Update the height because adding a graph vertically will interact with
# the plot height calculated for the table
fig.layout.update({'height':800})


fig.show()
